# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
QiskitRuntimeService.save_account(
token="wueCFNczdEGz9kkZLgK581qZi0kozRrDf1xDkmHbrMRE", # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard
instance="crn:v1:bluemix:public:quantum-computing:us-east:a/613a61c50fc747719de348aaceb88f64:c1db5104-27cd-4139-afca-f5283933bcc1::", # Optional
)
# Out:
# ---------------------------------------------------------------------------
# AccountAlreadyExistsError                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from qiskit_ibm_runtime import QiskitRuntimeService
# ----> 3 QiskitRuntimeService.save_account(
#       4 token="wueCFNczdEGz9kkZLgK581qZi0kozRrDf1xDkmHbrMRE", # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard
#       5 instance="crn:v1:bluemix:public:quantum-computing:us-east:a/613a61c50fc747719de348aaceb88f64:c1db5104-27cd-4139-afca-f5283933bcc1::", # Optional
#       6 )
#
# File ~/tais/helloWorldQuantum/ambiente/lib/python3.12/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:840, in QiskitRuntimeService.save_account(token, url, instance, channel, filename, name, proxies, verify, overwrite, set_as_default, private_endpoint, region, plans_preference, tags)
#     789 @staticmethod
#     790 def save_account(
# ...

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Run every time you need the service
service = QiskitRuntimeService()
service.backends()
# Out:
# [<IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_marrakesh')>]

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler import generate_preset_pass_manager
from qiskit_ibm_runtime import EstimatorV2 as Estimator
 
# Create a new circuit with two qubits
qc = QuantumCircuit(2)
 
# Add a Hadamard gate to qubit 0 
qc.h(0)
 
# Perform a controlled-X gate on qubit 1, controlled by qubit 0 ##Entrelazamiento
qc.cx(0, 1)
 
# Return a drawing of the circuit using MatPlotLib ("mpl").
# These guides are written by using Jupyter notebooks, which
# display the output of the last line of each cell.
# If you're running this in a script, use `print(qc.draw())` to
# print a text drawing.
qc.draw("mpl")

# %%
# Set up six different observables.
 
observables_labels = ["IZ", "IX", "ZI", "XI", "ZZ", "XX"]
observables = [SparsePauliOp(label) for label in observables_labels]

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
service = QiskitRuntimeService() #Conecto  a IBM Quantum
 
backend = service.least_busy(simulator=False, operational=True) #elijo un comutador cuantico, el que tenga menos espera en cola
 
# Convert to an ISA circuit and layout-mapped observables.
pm = generate_preset_pass_manager(backend=backend, optimization_level=1) #Transpilador
isa_circuit = pm.run(qc) #Circuito adaptado
 
isa_circuit.draw("mpl", idle_wires=False)
